# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Constant trong tensorflow

# %%
import tensorflow.compat.v1 as tf
x = tf.constant(5,tf.float32)
y = tf.constant([5], tf.float32)
z = tf.constant([5,3,4], tf.float32)
t = tf.constant([[5,3,4,6],[2,3,4,7]], tf.float32)
u = tf.constant([[[5,3,4,6],[2,3,4,0]]], tf.float32)
v = tf.constant([[[5,3,4,6],[2,3,4,0]],[[5,3,4,6],[2,3,4,0]],[[5,3,4,6],[2,3,4,0]]], tf.float32)
print(y)
# Out:
# Tensor("Const_5:0", shape=(1,), dtype=float32)

# %% [markdown]
# Variable trong tensorflow

# %%
import tensorflow.compat.v1 as tf
tf.compat.v1.disable_eager_execution()
x1 = tf.Variable(5.3, tf.float32)
x2 = tf.Variable(4.3, tf.float32)
x = tf.multiply(x1,x2)
init = tf.global_variables_initializer()
with tf.Session() as sess:
    sess.run(init)
    t = sess.run(x)
    print(t)
#==================================
x1 = tf.Variable([[5.3,4.5,6.0],[4.3,4.3,7.0]], tf.float32)
x2 = tf.Variable([[4.3,4.3,7.0],[5.3,4.5,6.0]], tf.float32)
x = tf.multiply(x1,x2)
init = tf.global_variables_initializer()
with tf.Session() as sess:
    sess.run(init)
    t = sess.run(x)
    print(t)
# Out:
# 22.79
# [[22.79 19.35 42.  ]
#  [22.79 19.35 42.  ]]

# %% [markdown]
# Placeholder

# %%
import tensorflow.compat.v1 as tf
tf.compat.v1.disable_eager_execution()
x = tf.placeholder(tf.float32,None)
y = tf.add(x,x)
with tf.Session() as sess:
    x_data= 5
    result = sess.run(y,feed_dict={x:x_data})
    print(result)
# Out:
# 10.0

# %%
x = tf.placeholder(tf.float32,[None,3])
y = tf.add(x,x)
with tf.Session() as sess:
    x_data= [[1.5, 2.0, 3.3]]
    result = sess.run(y,feed_dict={x:x_data})
    print(result)
# Out:
# [[3.  4.  6.6]]

# %%
x = tf.placeholder(tf.float32,[None,None,3])
y = tf.add(x,x)
with tf.Session() as sess:
    x_data= [[[1,2,3]]]
    result = sess.run(y,feed_dict={x:x_data})
    print(result)
# Out:
# [[[2. 4. 6.]]]

# %%
x = tf.placeholder(tf.float32,[None,4,3])
y = tf.add(x,x)
with tf.Session() as sess:
    x_data= [[[1,2,3],[2,3,4],[2,3,5],[0,1,2]]]
    result = sess.run(y,feed_dict={x:x_data})
    print(result)
# Out:
# [[[ 2.  4.  6.]
#   [ 4.  6.  8.]
#   [ 4.  6. 10.]
#   [ 0.  2.  4.]]]

# %%
x = tf.placeholder(tf.float32,[2,4,3])
y = tf.add(x,x)
with tf.Session() as sess:
    x_data= [[[1,2,3],[2,3,4],[2,3,5],[0,1,2]],[[1,2,3],[2,3,4],[2,3,5],[0,1,2]]]
    result = sess.run(y,feed_dict={x:x_data})
    print(result)
# Out:
# [[[ 2.  4.  6.]
#   [ 4.  6.  8.]
#   [ 4.  6. 10.]
#   [ 0.  2.  4.]]
#
#  [[ 2.  4.  6.]
#   [ 4.  6.  8.]
#   [ 4.  6. 10.]
#   [ 0.  2.  4.]]]

# %%
x = tf.placeholder(tf.float32,[2,4,3])
y = tf.placeholder(tf.float32,[2,4,3])
z = tf.add(x,y)
u = tf.multiply(x,y)
with tf.Session() as sess:
    x_data= [[[1,2,3],[2,3,4],[2,3,5],[0,1,2]],[[1,2,3],[2,3,4],[2,3,5],[0,1,2]]]
    y_data= [[[1,2,3],[2,3,4],[2,3,5],[0,1,2]],[[1,2,3],[2,3,4],[2,3,5],[0,1,2]]]
    result1 = sess.run(z,feed_dict={x:x_data, y:y_data})
    result2 = sess.run(u,feed_dict={x:x_data, y:y_data})
    print("result1 =", result1)
    print("result2 =", result2)
# Out:
# result1 = [[[ 2.  4.  6.]
#   [ 4.  6.  8.]
#   [ 4.  6. 10.]
#   [ 0.  2.  4.]]
#
#  [[ 2.  4.  6.]
#   [ 4.  6.  8.]
#   [ 4.  6. 10.]
#   [ 0.  2.  4.]]]
# result2 = [[[ 1.  4.  9.]
#   [ 4.  9. 16.]
#   [ 4.  9. 25.]
#   [ 0.  1.  4.]]
#
#  [[ 1.  4.  9.]
#   [ 4.  9. 16.]
#   [ 4.  9. 25.]
#   [ 0.  1.  4.]]]

# %% [markdown]
# Operation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import tensorflow.compat.v1 as tf
tf.compat.v1.disable_eager_execution()
x1 = tf.constant(5.3, tf.float32)
x2 = tf.constant(1.5, tf.float32)
w1 = tf.Variable(0.7, tf.float32)
w2 = tf.Variable(0.5, tf.float32)
u = tf.multiply(x1,w1)
v = tf.multiply(x2,w2)
z = tf.add(u,v)
result = tf.sigmoid(z)
init = tf.global_variables_initializer()
with tf.Session() as sess:
    sess.run(init)
    print(sess.run(result))
# Out:
# 0.9885698

# %%
x1 = tf.placeholder(tf.float32,[None,3])
x2 = tf.placeholder(tf.float32,[None,3])
w1 = tf.Variable([0.5,0.4,0.7],tf.float32)
w2 = tf.Variable([0.8,0.5,0.6], tf.float32)
u1 = tf.multiply(w1,x1)
u2 = tf.multiply(w2,x2)
v = tf.add(u1,u2)
z = tf.sigmoid(v)
init = tf.global_variables_initializer()
with tf.Session() as sess:
    x1_data= [[1,2,3]]
    x2_data= [[1,2,3]]
    sess.run(init)
    result = sess.run(z,feed_dict={x1:x1_data, x2:x2_data})
    print(result)
# Out:
# [[0.785835   0.85814893 0.9801597 ]]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Model Neuron Network

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
X=tf.constant([2,3,4],tf.float32)
w=tf.Variable([0.05,0.07,0.09],tf.float32)
a=tf.multiply(X,w)
a=tf.reduce_sum(a)
b=tf.Variable(0.6,tf.float32)
z=tf.add(a,b)
result1=tf.nn.tanh(z)
result2=tf.nn.sigmoid(z)
result3=tf.nn.relu(z)
result4=tf.nn.elu(z)
result5=tf.nn.relu6(z)
result6=tf.nn.softplus(z)
result7=tf.nn.softsign(z)
init=tf.global_variables_initializer()
with tf.Session() as sess:
    sess.run(init)
    print(sess.run(result1))
    print(sess.run(result2))
    print(sess.run(result3))
    print(sess.run(result4))
    print(sess.run(result5))
    print(sess.run(result6))
    print(sess.run(result7))
# Out:
# 0.8537976
# 0.78074276
# 1.27
# 1.27
# 1.27
# 1.5175096
# 0.55947137

# %% [markdown]
# 2. Xem cấu trúc phức tạp hơn trong Hình

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Một Neuron có CT:
# ###    z=x1*w1+x2*w2+...+xn*wn+bias
# ###    A=f(z)
# ###    trong đó:f là hàm kích hoạt,có thể là hàm RELU,Sigmoid,...
# # Một mạng neuron gồm:
# ###    -dữ liệu đầu vào(input data)
# ###    -dữ liệu đầu ra là phân lớp các loại nhãn
# ###    -các lớp ẩn là tập hợp các neuron được tính toán như công thức

# %% [markdown]
# 3.chạy ví dụ (tài liệu [0.2] trang 13)

# %%
#khai báo thư viện
from keras.models import Sequential#mô hình tuần tự
from keras.layers import Dense#lớp ẩn Dense
import numpy as np#thư viện numpy
# Getting the data ready---chuẩn bị tập dữ liệu
# Generate train dummy data for 1000 Students and dummy test for 500---bộ dữ liệu train gồm 1000,test gồm 500
#Columns :Age, Hours of Study &Avg Previous test scores--- các trường tuổi,giờ học,điểm trung bình các bài test
np.random.seed(2018) #Setting seed for reproducibility---thiết lập điều khiển giá trị random
train_data, test_data = np.random.random((1000, 3)),np.random.random((500, 3))#khởi tạo bộ dữ liệu train,test
#Generate dummy results for 1000 students : Whether Passed (1) or Failed (0)---1 là đỗ,0 là trượt
labels = np.random.randint(2, size=(1000, 1))#thiết lập nhãn cho bộ train
#Defining the model structure with the required layers,of neurons, activation function and optimizers
model = Sequential()#khởi tạo mô hình tuần tự
model.add(Dense(5, input_dim=3, activation='relu'))#thêm lớp ẩn với 5 neurons hàm kích hoạt relu
model.add(Dense(4, activation='relu'))#thêm lớp ẩn với 4 neurons hàm kích hoạt relu
model.add(Dense(1, activation='sigmoid'))#thêm lớp đầu ra với 1 neurons hàm kích hoạt sigmoid
#mô hình có sử dụng hàm binary_crossentropy làm hàm lỗi,hàm tối ưu Adam,thông số đánh giá accuracy
model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])
#Train the model and make predictions---tiến hành huấn luyện mô hình 10 lần.
model.fit(train_data, labels, epochs=10, batch_size=32)
#Make predictions from the trained model---tiến hành dự đoán bộ test trên cơ sở mô hình huấn luyện của bộ train
predictions = model.predict(test_data)
# Out:
# Train on 1000 samples
# Epoch 1/10
# 1000/1000 [==============================] - 0s 115us/sample - loss: 0.7044 - accuracy: 0.4810
# Epoch 2/10
# 1000/1000 [==============================] - 0s 36us/sample - loss: 0.6991 - accuracy: 0.4890
# Epoch 3/10
# 1000/1000 [==============================] - 0s 33us/sample - loss: 0.6968 - accuracy: 0.4970
# Epoch 4/10
# 1000/1000 [==============================] - 0s 35us/sample - loss: 0.6956 - accuracy: 0.5040
# Epoch 5/10
# 1000/1000 [==============================] - 0s 37us/sample - loss: 0.6950 - accuracy: 0.4950
# Epoch 6/10
# 1000/1000 [==============================] - 0s 34us/sample - loss: 0.6947 - accuracy: 0.4990
# Epoch 7/10
# 1000/1000 [==============================] - 0s 39us/sample - loss: 0.6944 - accuracy: 0.4960
# Epoch 8/10
# 1000/1000 [==============================] - 0s 34us/sample - loss: 0.6942 - accuracy: 0.4920
# Epoch 9/10
# 1000/1000 [==============================] - 0s 34us/sample - loss: 0.6940 - accuracy: 0.4860
# Epoch 10/10
# 1000/1000 [==============================] - 0s 35us/sample - loss: 0.6938 - accuracy: 0.4870

# %%
predictions
# Out:
# array([[0.4792603 ],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.5094363 ],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.4816652 ],
#        [0.48457503],
#        [0.4812409 ],
#        [0.49908492],
#        [0.492951  ],
#        [0.49969676],
#        [0.48457503],
#        [0.482498  ],
#        [0.4993554 ],
#        [0.48491853],
#        [0.512879  ],
#        [0.48264763],
#        [0.51738495],
#        [0.50920516],
#        [0.4951203 ],
#        [0.4814013 ],
#        [0.48457503],
#        [0.4816473 ],
#        [0.48183095],
#        [0.51906395],
#        [0.4809649 ],
#        [0.48457503],
#        [0.48373124],
#        [0.48457503],
#        [0.48457503],
#        [0.52388304],
#        [0.48457503],
#        [0.49232787],
#        [0.48457503],
#        [0.5258262 ],
#        [0.48550203],
#        [0.48457503],
#        [0.48457503],
#        [0.48969746],
#        [0.48457503],
#        [0.4883237 ],
#        [0.48457503],
#        [0.48589694],
#        [0.48320568],
#        [0.48270053],
#        [0.5372725 ],
#        [0.48860773],
#        [0.48115885],
#        [0.48457503],
#        [0.51071733],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.4919521 ],
#        [0.48457503],
#        [0.49924257],
#        [0.48244485],
#        [0.48457503],
#        [0.5302082 ],
#        [0.5072918 ],
#        [0.48457503],
#        [0.47927883],
#        [0.51832485],
#        [0.48252314],
#        [0.48107043],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.47931767],
#        [0.52596486],
#        [0.49952242],
#        [0.4816177 ],
#        [0.5314752 ],
#        [0.525281  ],
#        [0.49026558],
#        [0.48298457],
#        [0.4907183 ],
#        [0.48457503],
#        [0.48080596],
#        [0.48457503],
#        [0.48457503],
#        [0.4994026 ],
#        [0.48457503],
#        [0.48109624],
#        [0.48457503],
#        [0.49167785],
#        [0.51009566],
#        [0.48457503],
#        [0.48457503],
#        [0.49092165],
#        [0.5306823 ],
#        [0.49199834],
#        [0.48899487],
#        [0.4822321 ],
#        [0.4855787 ],
#        [0.48233157],
#        [0.5156443 ],
#        [0.48062164],
#        [0.48196068],
#        [0.48457503],
#        [0.48205742],
#        [0.5195423 ],
#        [0.48457503],
#        [0.48457503],
#        [0.52092445],
#        [0.4839165 ],
#        [0.48457503],
#        [0.48111787],
#        [0.5001014 ],
#        [0.48457503],
#        [0.48457503],
#        [0.48343664],
#        [0.48457503],
#        [0.47898582],
#        [0.48457503],
#        [0.48877686],
#        [0.48169044],
#        [0.48457503],
#        [0.5021986 ],
#        [0.48457503],
#        [0.5199077 ],
#        [0.49736476],
#        [0.49208143],
#        [0.48600826],
#        [0.53245413],
#        [0.48457503],
#        [0.48457503],
#        [0.48419732],
#        [0.516311  ],
#        [0.48731217],
#        [0.48640168],
#        [0.47936863],
#        [0.48620448],
#        [0.48457503],
#        [0.48457503],
#        [0.49862456],
#        [0.4793746 ],
#        [0.48457503],
#        [0.48064885],
#        [0.48457503],
#        [0.47999832],
#        [0.48457503],
#        [0.48605767],
#        [0.49603903],
#        [0.48338875],
#        [0.48076046],
#        [0.5244227 ],
#        [0.4842292 ],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.48248732],
#        [0.4993485 ],
#        [0.48005727],
#        [0.480831  ],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.48033375],
#        [0.48115575],
#        [0.51050603],
#        [0.4814005 ],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.48046926],
#        [0.49137077],
#        [0.48657385],
#        [0.49337777],
#        [0.4928774 ],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.488784  ],
#        [0.5049736 ],
#        [0.49596187],
#        [0.48457503],
#        [0.48457503],
#        [0.49847612],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.48212978],
#        [0.5155382 ],
#        [0.48457503],
#        [0.49447468],
#        [0.48818746],
#        [0.48037675],
#        [0.5049186 ],
#        [0.48457503],
#        [0.52430385],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.52387667],
#        [0.48457503],
#        [0.48464152],
#        [0.48457503],
#        [0.5234909 ],
#        [0.48457503],
#        [0.50267184],
#        [0.4847391 ],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.54349464],
#        [0.500659  ],
#        [0.5014505 ],
#        [0.48470992],
#        [0.49136558],
#        [0.49911308],
#        [0.48111907],
#        [0.48457503],
#        [0.49712923],
#        [0.48429883],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.4817115 ],
#        [0.48457503],
#        [0.49170372],
#        [0.50079995],
#        [0.4806555 ],
#        [0.49547178],
#        [0.4847654 ],
#        [0.4901629 ],
#        [0.48457503],
#        [0.48457503],
#        [0.48251042],
#        [0.52552754],
#        [0.48457503],
#        [0.48003846],
#        [0.48411164],
#        [0.48204628],
#        [0.48457503],
#        [0.49602985],
#        [0.48457503],
#        [0.51456445],
#        [0.5234071 ],
#        [0.53863263],
#        [0.52018636],
#        [0.48103583],
#        [0.48563585],
#        [0.48457503],
#        [0.502221  ],
#        [0.49890462],
#        [0.48457503],
#        [0.5065443 ],
#        [0.48457503],
#        [0.4838461 ],
#        [0.5096472 ],
#        [0.48457503],
#        [0.48457503],
#        [0.4850461 ],
#        [0.48682213],
#        [0.50001246],
#        [0.48457503],
#        [0.51182985],
#        [0.4896915 ],
#        [0.51311743],
#        [0.48208848],
#        [0.48457503],
#        [0.48457503],
#        [0.49047253],
#        [0.47889253],
#        [0.48414966],
#        [0.49154302],
#        [0.48457503],
#        [0.53132516],
#        [0.48457503],
#        [0.53464746],
#        [0.48457503],
#        [0.50596064],
#        [0.47991067],
#        [0.48457503],
#        [0.479374  ],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.4822089 ],
#        [0.4937877 ],
#        [0.4828109 ],
#        [0.48457503],
#        [0.48457503],
#        [0.48516464],
#        [0.48323917],
#        [0.54669946],
#        [0.48457503],
#        [0.48542824],
#        [0.48859653],
#        [0.5245114 ],
#        [0.4812282 ],
#        [0.4795465 ],
#        [0.4846046 ],
#        [0.48046404],
#        [0.48457503],
#        [0.48329386],
#        [0.5028886 ],
#        [0.4803373 ],
#        [0.4916073 ],
#        [0.4803188 ],
#        [0.5101946 ],
#        [0.4789583 ],
#        [0.5030939 ],
#        [0.48544946],
#        [0.5061515 ],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.48747268],
#        [0.4829644 ],
#        [0.4980916 ],
#        [0.48465052],
#        [0.50219554],
#        [0.48457503],
#        [0.48633558],
#        [0.51029354],
#        [0.5045726 ],
#        [0.48457503],
#        [0.5159125 ],
#        [0.51081604],
#        [0.48477578],
#        [0.48457503],
#        [0.5052866 ],
#        [0.48646423],
#        [0.48457503],
#        [0.49372306],
#        [0.48457503],
#        [0.48457503],
#        [0.54072654],
#        [0.48457503],
#        [0.4887125 ],
#        [0.48457503],
#        [0.47920984],
#        [0.47949797],
#        [0.5276063 ],
#        [0.48239312],
#        [0.48457503],
#        [0.50715697],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.5227168 ],
#        [0.5007276 ],
#        [0.47987452],
#        [0.47997782],
#        [0.48109272],
#        [0.48457503],
#        [0.48415932],
#        [0.49271855],
#        [0.48457503],
#        [0.48649004],
#        [0.5026209 ],
#        [0.49328655],
#        [0.48255384],
#        [0.48457503],
#        [0.48457503],
#        [0.53653693],
#        [0.5328158 ],
#        [0.48457503],
#        [0.50533986],
#        [0.5080777 ],
#        [0.48457503],
#        [0.48497316],
#        [0.48457503],
#        [0.47891623],
#        [0.5278719 ],
#        [0.48457503],
#        [0.48296246],
#        [0.48457503],
#        [0.48631677],
#        [0.48700824],
#        [0.5331927 ],
#        [0.48457503],
#        [0.48457503],
#        [0.49911734],
#        [0.48950258],
#        [0.49765864],
#        [0.5049223 ],
#        [0.5160947 ],
#        [0.48457503],
#        [0.48457503],
#        [0.5250706 ],
#        [0.51756936],
#        [0.47904947],
#        [0.51555634],
#        [0.49053264],
#        [0.48457503],
#        [0.48457503],
#        [0.50008583],
#        [0.48998562],
#        [0.48626882],
#        [0.4792352 ],
#        [0.48457503],
#        [0.5035269 ],
#        [0.5023012 ],
#        [0.4846566 ],
#        [0.48457503],
#        [0.48396796],
#        [0.48011646],
#        [0.51651883],
#        [0.48457503],
#        [0.48457503],
#        [0.48948714],
#        [0.48172402],
#        [0.48457503],
#        [0.49682128],
#        [0.48457503],
#        [0.48457503],
#        [0.4987423 ],
#        [0.48457503],
#        [0.48463356],
#        [0.48457503],
#        [0.4870717 ],
#        [0.48457503],
#        [0.48457503],
#        [0.48586875],
#        [0.4875311 ],
#        [0.49240664],
#        [0.48457503],
#        [0.4803752 ],
#        [0.48147243],
#        [0.5235713 ],
#        [0.48745346],
#        [0.48457503],
#        [0.48457503],
#        [0.48457503],
#        [0.4953622 ],
#        [0.48084304],
#        [0.48185754],
#        [0.5044078 ],
#        [0.5101747 ],
#        [0.5054844 ],
#        [0.4989659 ],
#        [0.48457503],
#        [0.48457503],
#        [0.49722508],
#        [0.5314165 ],
#        [0.48640695],
#        [0.48457503],
#        [0.48457503],
#        [0.4915616 ],
#        [0.50706875],
#        [0.48664773],
#        [0.50093764],
#        [0.48558584],
#        [0.53239065],
#        [0.49677595],
#        [0.48582137],
#        [0.48457503],
#        [0.49389818],
#        [0.47987375],
#        [0.479571  ],
#        [0.48487848],
#        [0.49029556],
#        [0.48457503],
#        [0.5073203 ],
#        [0.48457503],
#        [0.525413  ],
#        [0.5080454 ],
#        [0.48457503],
#        [0.4802855 ],
#        [0.48441535],
#        [0.48457503],
#        [0.48456165],
#        [0.48457503],
#        [0.50140905],
#        [0.49224222],
#        [0.5039043 ],
#        [0.47956005],
#        [0.48457503],
#        [0.48457503],
#        [0.5178518 ],
#        [0.48457503],
#        [0.49184301],
#        [0.48457503],
#        [0.5040907 ],
#        [0.48545587],
#        [0.5022677 ],
#        [0.48291686],
#        [0.48457503],
#        [0.48147342],
#        [0.4944685 ],
#        [0.48457503],
#        [0.4980363 ],
#        [0.48401618],
#        [0.49817288]], dtype=float32)

# %% [markdown]
# 4.Chạy ví dụ(tài liệu [0.2])

# %%
#khai báo thư viện
import numpy as np#thư viện numpy
from keras.models import Sequential#mô hình tuần tự
from keras.layers import Dense, Activation#lớp Dense
# Generate dummy training dataset---khởi tạo bộ dữ liệu train
np.random.seed(2018)
x_train = np.random.random((6000,10))
y_train = np.random.randint(2, size=(6000, 1))
# Generate dummy validation dataset---khởi tạo bộ dữ liệu validation
x_val = np.random.random((2000,10))
y_val = np.random.randint(2, size=(2000, 1))
# Generate dummy test dataset---khởi tạo bộ dữ liệu test
x_test = np.random.random((2000,10))
y_test = np.random.randint(2, size=(2000, 1))
#Define the model architecture---cấu trúc của mạng(mô hình)
model = Sequential()#khởi tạo mô hình tuần tự
model.add(Dense(64, input_dim=10,activation = "relu")) #Layer 1:gồm 64 neurons nhận đầu vào 10,hàm kích hoạt relu
model.add(Dense(32,activation = "relu")) #Layer 2:gồm 32 neurons,hàm kích hoạt relu
model.add(Dense(16,activation = "relu")) #Layer 3:gồm 16 neurons,hàm kích hoạt relu
model.add(Dense(8,activation = "relu")) #Layer 4:gồm 8 neurons,hàm kích hoạt relu
model.add(Dense(4,activation = "relu")) #Layer 5:gồm 4 neurons,hàm kích hoạt relu
model.add(Dense(1,activation = "sigmoid")) #OutputLayer:hàm kích hoạt sigmoid
#Configure the model---định cấu hình mô hình:hàm tối ưu Adam,hàm lỗi binary_crossentropy,thông số đánh giá:accuracy
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])
#Train the model---tiến hành huấn luyện mô hình
model.fit(x_train, y_train, batch_size=64, epochs=3,validation_data=(x_val,y_val))
#evaluate(x=None, y=None, batch_size=None, verbose=1,sample_weight=None, steps=None)---đánh giá mô hình:thông số loss,accuracy
print(model.evaluate(x_test,y_test))
print(model.metrics_names)
#print 10 predictions---hiển thị 10 giá trị dự đoán đầu
pred = model.predict(x_test)
pred[:10]
# Out:
# Train on 6000 samples, validate on 2000 samples
# Epoch 1/3
# 6000/6000 [==============================] - 0s 64us/sample - loss: 0.6934 - accuracy: 0.4918 - val_loss: 0.6932 - val_accuracy: 0.4865
# Epoch 2/3
# 6000/6000 [==============================] - 0s 26us/sample - loss: 0.6931 - accuracy: 0.5072 - val_loss: 0.6931 - val_accuracy: 0.4985
# Epoch 3/3
# 6000/6000 [==============================] - 0s 27us/sample - loss: 0.6931 - accuracy: 0.5042 - val_loss: 0.6932 - val_accuracy: 0.4970
# [0.6927854132652282, 0.52]
# ['loss', 'accuracy']
# array([[0.50444967],
#        [0.50353026],
#        [0.5038278 ],
#        [0.5012785 ],
#        [0.5034331 ],
#        [0.5040945 ],
#        [0.5001062 ],
#        [0.50363815],
#        [0.5033947 ],
#        [0.50343   ]], dtype=float32)

# %% [markdown]
# 5.chạy ví dụ chap 3[0.2]

# %%
#Exploring the Data
import pandas as pd
df=pd.read_csv('train.csv')
# Out:
# C:\Users\Dell Precision 7510\AppData\Local\Temp\ipykernel_12872\3216605758.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('train.csv')

# %%
df.shape
# Out:
# (1017209, 9)

# %%
df.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
store=pd.read_csv('store.csv')
store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %%
#Looking at the Data Dictionary
df_new = df.merge(store,on=["Store"], how="inner")
print(df_new.shape)
# Out:
# (1017209, 18)

# %%
print("Distinct number of Stores :", len(df_new["Store"].unique()))
print("Distinct number of Days :", len(df_new["Date"].unique()))
print("Average daily sales of all stores : ",round(df_new["Sales"].mean(),2))
# Out:
# Distinct number of Stores : 1115
# Distinct number of Days : 942
# Average daily sales of all stores :  5773.82

# %%
#Finding Data Types
df_new.dtypes
# Out:
# Store                          int64
# DayOfWeek                      int64
# Date                          object
# Sales                          int64
# Customers                      int64
# Open                           int64
# Promo                          int64
# StateHoliday                  object
# SchoolHoliday                  int64
# StoreType                     object
# Assortment                    object
# CompetitionDistance          float64
# CompetitionOpenSinceMonth    float64
# CompetitionOpenSinceYear     float64
# Promo2                         int64
# Promo2SinceWeek              float64
# Promo2SinceYear              float64
# PromoInterval                 object
# dtype: object

# %%
#Working with Time
df_new["DayOfWeek"].value_counts()
# Out:
# 5    145845
# 4    145845
# 3    145665
# 2    145664
# 1    144730
# 7    144730
# 6    144730
# Name: DayOfWeek, dtype: int64

# %%
#We can extract all date properties from a datetime datatype
import numpy as np
df_new['Date'] = pd.to_datetime(df_new['Date'], infer_datetime_format=True)
df_new["Month"] = df_new["Date"].dt.month
df_new["Quarter"] = df_new["Date"].dt.quarter
df_new["Year"] = df_new["Date"].dt.year
df_new["Day"] = df_new["Date"].dt.day
df_new["Week"] = df_new["Date"].dt.week
df_new["Season"] = np.where(df_new["Month"].isin([3,4,5]),"Spring",np.where(df_new["Month"].isin([6,7,8]),"Summer",np.where(df_new["Month"].isin([9,10,11]),"Fall",np.where(df_new["Month"].isin([12,1,2]),"Winter","None"))))
#Using the head command to view (only) the data and the newly engineered features
print(df_new[["Date","Year","Month","Day","Week","Quarter","Season"]].head())
# Out:
# C:\Users\Dell Precision 7510\AppData\Local\Temp\ipykernel_12872\770477302.py:8: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df_new["Week"] = df_new["Date"].dt.week
#         Date  Year  Month  Day  Week  Quarter  Season
# 0 2015-07-31  2015      7   31    31        3  Summer
# 1 2015-07-30  2015      7   30    31        3  Summer
# 2 2015-07-29  2015      7   29    31        3  Summer
# 3 2015-07-28  2015      7   28    31        3  Summer
# 4 2015-07-27  2015      7   27    31        3  Summer

# %%
#Predicting Sales
#Import matplotlib, python most popular data visualizing library
import matplotlib.pyplot as plt
# %matplotlib inline
#Create a histogram to study the Daily Sales for the stores
plt.figure(figsize=(15,8))
plt.hist(df_new["Sales"])
plt.title("Histogram for Store Sales")
plt.xlabel("bins")
plt.xlabel("Frequency")
plt.show()

# %%
#Exploring Numeric Columns
#Use the histogram function provided by the Pandas object
#The function returns a cross-tab histogram plot for all numeric columns in the data
df_new.hist(figsize=(20,10));

# %%
df_new.isnull().sum()/df_new.shape[0] * 100
# Out:
# Store                         0.000000
# DayOfWeek                     0.000000
# Date                          0.000000
# Sales                         0.000000
# Customers                     0.000000
# Open                          0.000000
# Promo                         0.000000
# StateHoliday                  0.000000
# SchoolHoliday                 0.000000
# StoreType                     0.000000
# Assortment                    0.000000
# CompetitionDistance           0.259730
# CompetitionOpenSinceMonth    31.787764
# CompetitionOpenSinceYear     31.787764
# Promo2                        0.000000
# Promo2SinceWeek              49.943620
# Promo2SinceYear              49.943620
# PromoInterval                49.943620
# Month                         0.000000
# Quarter                       0.000000
# Year                          0.000000
# Day                           0.000000
# Week                          0.000000
# Season                        0.000000
# dtype: float64

# %%
#Replace nulls with the mode
df_new["CompetitionDistance"]=df_new["CompetitionDistance"].fillna(df_new["CompetitionDistance"].mode()[0])
#Double check if we still see nulls for the column
df_new["CompetitionDistance"].isnull().sum()/df_new.shape[0] * 100
# Out:
# 0.0

# %%
#Understanding the Categorical Features
import seaborn as sns #Seaborn is another powerful visualization library for Python
sns.set(style="whitegrid")
#Create the bar plot for Average Sales across different Seasons
ax = sns.barplot(x="Season", y="Sales", data=df_new)

# %%
#Create the bar plot for Average Sales across different Assortments
ax = sns.barplot(x="Assortment", y="Sales", data=df_new)

# %%
#Create the bar plot for Average Sales across different Store Types
ax = sns.barplot(x="StoreType", y="Sales", data=df_new)

# %%
#Data Engineering
#Define a variable for each type of feature
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
target = ["Sales"]
numeric_columns = ["Customers","Open","Promo","Promo2","StateHoliday","SchoolHoliday","CompetitionDistance"]
categorical_columns = ["DayOfWeek","Quarter","Month","Year","StoreType","Assortment","Season"]
#Define a function that will intake the raw dataframe and the column name and return a one hot encoded DF
def create_ohe(df, col):
    le = LabelEncoder()
    a=le.fit_transform(df_new[col]).reshape(-1,1)
    ohe = OneHotEncoder(sparse=False)
    column_names = [col+ "_"+ str(i) for i in le.classes_]
    return(pd.DataFrame(ohe.fit_transform(a),columns =column_names))
#Since the above function converts the column, one at a time
#We create a loop to create the final dataset with all features
temp = df_new[numeric_columns]
for column in categorical_columns:
    temp_df = create_ohe(df_new,column)
    temp = pd.concat([temp,temp_df],axis=1)
print("Shape of Data:",temp.shape)
print("Distinct Datatypes:",temp.dtypes.unique())
# Out:
# Shape of Data: (1017209, 44)
# Distinct Datatypes: [dtype('int64') dtype('O') dtype('float64')]

# %%
print(temp.columns[temp.dtypes=="object"])
# Out:
# Index(['StateHoliday'], dtype='object')

# %%
temp["StateHoliday"].unique()
# Out:
# array(['0', 'a', 'b', 'c', 0], dtype=object)

# %%
temp["StateHoliday"]= np.where(temp["StateHoliday"]== '0',0,1)
#One last check of the data type
temp.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('int32'), dtype('float64')], dtype=object)

# %%
from sklearn.model_selection import train_test_split
#Create train and test dataset with an 80:20 split
x_train, x_test, y_train, y_test = train_test_split(temp,df_new[target],test_size=0.2,random_state=2018)
#Further divide training dataset into train and validation dataset with an 90:10 split
x_train, x_val, y_train, y_val = train_test_split(x_train,
y_train,test_size=0.1,random_state=2018)
#Check the sizes of all newly created datasets
print("Shape of x_train:",x_train.shape)
print("Shape of x_val:",x_val.shape)
print("Shape of x_test:",x_test.shape)
print("Shape of y_train:",y_train.shape)
print("Shape of y_val:",y_val.shape)
print("Shape of y_test:",y_test.shape)
# Out:
# Shape of x_train: (732390, 44)
# Shape of x_val: (81377, 44)
# Shape of x_test: (203442, 44)
# Shape of y_train: (732390, 1)
# Shape of y_val: (81377, 1)
# Shape of y_test: (203442, 1)

# %%
#Defining Model Baseline Performance
#calculate the average score of the train dataset
mean_sales = y_train.mean()
print("Average Sales :",mean_sales)
# Out:
# Average Sales : Sales    5773.099997
# dtype: float64

# %%
#Calculate the Mean Absolute Error on the test dataset
print("MAE for Test Data:",abs(y_test - mean_sales).mean()[0])
# Out:
# MAE for Test Data: 2883.587604303215

# %%
#Designing the DNN
#Create Deep Neural Network Architecture
from keras.models import Sequential
from keras.layers import Dense, Dropout
model = Sequential()
model.add(Dense(150,input_dim = 44,activation="relu"))
#The input_dim =44, since the width of the training data=44(refer data engg section)
model.add(Dense(1,activation = "linear"))
#Configure the model
model.compile(optimizer='adam',loss="mean_absolute_error",metrics=["mean_absolute_error"])
#Train the model
model.fit(x_train.values,y_train.values, validation_data=(x_val,y_val),epochs=10,batch_size=64)
# Out:
# Train on 732390 samples, validate on 81377 samples
# Epoch 1/10
# 730496/732390 [============================>.] - ETA: 0s - loss: 958.4317 - mean_absolute_error: 958.4315
# C:\Users\Dell Precision 7510\AppData\Roaming\Python\Python39\site-packages\keras\engine\training_v1.py:2332: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 732390/732390 [==============================] - 16s 22us/sample - loss: 958.0464 - mean_absolute_error: 958.0461 - val_loss: 829.8316 - val_mean_absolute_error: 829.8307
# Epoch 2/10
# 732390/732390 [==============================] - 20s 27us/sample - loss: 784.8320 - mean_absolute_error: 784.8303 - val_loss: 752.2093 - val_mean_absolute_error: 752.2091
# Epoch 3/10
# 732390/732390 [==============================] - 27s 36us/sample - loss: 739.6266 - mean_absolute_error: 739.6275 - val_loss: 720.6002 - val_mean_absolute_error: 720.6002
# Epoch 4/10
# 732390/732390 [==============================] - 14s 20us/sample - loss: 721.6038 - mean_absolute_error: 721.6022 - val_loss: 716.6656 - val_mean_absolute_error: 716.6658
# Epoch 5/10
# 732390/732390 [==============================] - 15s 20us/sample - loss: 710.2940 - mean_absolute_error: 710.2929 - val_loss: 707.7320 - val_mean_absolute_error: 707.7324
# Epoch 6/10
# 732390/732390 [==============================] - 22s 30us/sample - loss: 702.4003 - mean_absolute_error: 702.4001 - val_loss: 748.9942 - val_mean_absolute_error: 748.9948
# Epoch 7/10
# 732390/732390 [==============================] - 23s 32us/sample - loss: 696.6957 - mean_absolute_error: 696.6957 - val_loss: 701.8758 - val_mean_absolute_error: 701.8758
# Epoch 8/10
# 732390/732390 [==============================] - 24s 33us/sample - loss: 693.5112 - mean_absolute_error: 693.5125 - val_loss: 710.4097 - val_mean_absolute_error: 710.4097
# Epoch 9/10
# 732390/732390 [==============================] - 21s 29us/sample - loss: 688.1263 - mean_absolute_error: 688.1254 - val_loss: 695.2548 - val_mean_absolute_error: 695.2549
# Epoch 10/10
# 732390/732390 [==============================] - 19s 27us/sample - loss: 683.6420 - mean_absolute_error: 683.6415 - val_loss: 682.8114 - val_mean_absolute_error: 682.8119

# %%
#Testing the Model Performance
#Use the model's evaluate method to predict and evaluate the test datasets
result = model.evaluate(x_test.values,y_test.values)
#Print the results
for i in range(len(model.metrics_names)):
    print("Metric ",model.metrics_names[i],":",str(round(result[i],2)))
# Out:
# Metric  loss : 680.29
# Metric  mean_absolute_error : 680.28

# %%
#Improving the Model
model = Sequential()
model.add(Dense(150,input_dim = 44,activation="relu"))
model.add(Dense(150,activation="relu"))
model.add(Dense(150,activation="relu"))
model.add(Dense(1,activation = "linear"))
model.compile(optimizer='adam',loss="mean_squared_error",metrics=["mean_absolute_error"])
history = model.fit(x_train,y_train, validation_data=(x_val,y_val),epochs=10,batch_size=64)
#result = model.evaluate(x_test,y_test)
for i in range(len(model.metrics_names)):
    print("Metric ",model.metrics_names[i],":",str(round(result[i],2)))
# Out:
# Train on 732390 samples, validate on 81377 samples
# Epoch 1/10
# 732390/732390 [==============================] - 22s 30us/sample - loss: 1729159.4957 - mean_absolute_error: 853.9700 - val_loss: 1194126.9104 - val_mean_absolute_error: 731.3545
# Epoch 2/10
# 732390/732390 [==============================] - 28s 38us/sample - loss: 1148371.8158 - mean_absolute_error: 719.3988 - val_loss: 1055111.4263 - val_mean_absolute_error: 686.6689
# Epoch 3/10
# 732390/732390 [==============================] - 22s 30us/sample - loss: 1077523.2156 - mean_absolute_error: 696.9960 - val_loss: 992675.4775 - val_mean_absolute_error: 679.7256
# Epoch 4/10
# 732390/732390 [==============================] - 23s 32us/sample - loss: 1044290.1036 - mean_absolute_error: 686.2938 - val_loss: 995507.1871 - val_mean_absolute_error: 671.6569
# Epoch 5/10
# 732390/732390 [==============================] - 22s 30us/sample - loss: 1023237.9109 - mean_absolute_error: 679.9412 - val_loss: 986945.5271 - val_mean_absolute_error: 676.0681
# Epoch 6/10
# 732390/732390 [==============================] - 22s 30us/sample - loss: 991594.5860 - mean_absolute_error: 671.8822 - val_loss: 1027786.9233 - val_mean_absolute_error: 701.1517
# Epoch 7/10
# 732390/732390 [==============================] - 23s 31us/sample - loss: 968400.6413 - mean_absolute_error: 664.3875 - val_loss: 937393.4812 - val_mean_absolute_error: 661.5075
# Epoch 8/10
# 732390/732390 [==============================] - 22s 30us/sample - loss: 952882.1091 - mean_absolute_error: 659.6562 - val_loss: 898381.9611 - val_mean_absolute_error: 650.7033
# Epoch 9/10
# 732390/732390 [==============================] - 22s 30us/sample - loss: 933910.6234 - mean_absolute_error: 653.4972 - val_loss: 888571.7462 - val_mean_absolute_error: 640.7676
# Epoch 10/10
# 732390/732390 [==============================] - 24s 33us/sample - loss: 919155.3687 - mean_absolute_error: 648.2255 - val_loss: 911885.1229 - val_mean_absolute_error: 657.8572
# Metric  loss : 680.29
# Metric  mean_absolute_error : 680.28

# %%
#Increasing the Number of Neurons
model = Sequential()
model.add(Dense(350,input_dim = 44,activation="relu"))
model.add(Dense(350,activation="relu"))
model.add(Dense(1,activation = "linear"))
model.compile(optimizer='adam',loss="mean_squared_error",metrics=["mean_absolute_error"])
model.fit(x_train,y_train, validation_data=(x_val,y_val),
epochs=15,batch_size=64)
result = model.evaluate(x_test,y_test)
for i in range(len(model.metrics_names)):
    print("Metric ",model.metrics_names[i],":",str(round(result[i],2)))
# Out:
# Train on 732390 samples, validate on 81377 samples
# Epoch 1/15
# 732390/732390 [==============================] - 26s 36us/sample - loss: 1671162.6750 - mean_absolute_error: 842.9240 - val_loss: 1077966.9917 - val_mean_absolute_error: 702.0866
# Epoch 2/15
# 732390/732390 [==============================] - 28s 38us/sample - loss: 1142371.9451 - mean_absolute_error: 721.8632 - val_loss: 1086653.6308 - val_mean_absolute_error: 698.0053
# Epoch 3/15
# 732390/732390 [==============================] - 25s 35us/sample - loss: 1082086.0927 - mean_absolute_error: 702.5276 - val_loss: 1075821.9824 - val_mean_absolute_error: 699.8962
# Epoch 4/15
# 732390/732390 [==============================] - 25s 35us/sample - loss: 1052325.9429 - mean_absolute_error: 692.4466 - val_loss: 972539.2996 - val_mean_absolute_error: 665.1793
# Epoch 5/15
# 732390/732390 [==============================] - 27s 37us/sample - loss: 1028917.7131 - mean_absolute_error: 684.1906 - val_loss: 1017198.2726 - val_mean_absolute_error: 692.8645
# Epoch 6/15
# 732390/732390 [==============================] - 28s 39us/sample - loss: 1011592.6072 - mean_absolute_error: 678.7554 - val_loss: 936837.0843 - val_mean_absolute_error: 662.1467
# Epoch 7/15
# 732390/732390 [==============================] - 26s 35us/sample - loss: 991784.4256 - mean_absolute_error: 672.1454 - val_loss: 936006.3621 - val_mean_absolute_error: 655.9046
# Epoch 8/15
# 732390/732390 [==============================] - 26s 35us/sample - loss: 977436.1532 - mean_absolute_error: 667.7761 - val_loss: 935078.8097 - val_mean_absolute_error: 661.1219
# Epoch 9/15
# 732390/732390 [==============================] - 26s 35us/sample - loss: 963417.6368 - mean_absolute_error: 663.1313 - val_loss: 925866.8544 - val_mean_absolute_error: 664.7132
# Epoch 10/15
# 732390/732390 [==============================] - 30s 41us/sample - loss: 954018.9463 - mean_absolute_error: 660.3032 - val_loss: 937351.9819 - val_mean_absolute_error: 656.4594
# Epoch 11/15
# 732390/732390 [==============================] - 26s 35us/sample - loss: 941771.2362 - mean_absolute_error: 656.0631 - val_loss: 954609.9239 - val_mean_absolute_error: 663.5609
# Epoch 12/15
# 732390/732390 [==============================] - 26s 35us/sample - loss: 931694.1006 - mean_absolute_error: 652.5057 - val_loss: 886325.7749 - val_mean_absolute_error: 646.2419
# Epoch 13/15
# 732390/732390 [==============================] - 27s 36us/sample - loss: 921284.6998 - mean_absolute_error: 649.2896 - val_loss: 889316.9426 - val_mean_absolute_error: 645.3376
# Epoch 14/15
# 732390/732390 [==============================] - 26s 35us/sample - loss: 911737.1511 - mean_absolute_error: 646.3776 - val_loss: 885669.9189 - val_mean_absolute_error: 640.3536
# Epoch 15/15
# 732390/732390 [==============================] - 26s 35us/sample - loss: 901599.2676 - mean_absolute_error: 642.2762 - val_loss: 875855.0129 - val_mean_absolute_error: 644.3288
# Metric  loss : 874850.77
# Metric  mean_absolute_error : 640.06

# %%
from keras.callbacks import History
history = History()
model = Sequential()
model.add(Dense(350,input_dim = 44,activation="relu"))
model.add(Dense(350,activation="relu"))
model.add(Dense(350,activation="relu"))
model.add(Dense(350,activation="relu"))
model.add(Dense(350,activation="relu"))
model.add(Dense(1,activation = "linear"))
model.compile(optimizer='adam',loss="mean_squared_error",metrics=["mean_absolute_error"])
model.fit(x_train,y_train, validation_data=(x_val,y_val),epochs=15,batch_size=64,callbacks=[history])
result = model.evaluate(x_test,y_test)
for i in range(len(model.metrics_names)):
    print("Metric ",model.metrics_names[i],":",str(round(result[i],2)))
# Out:
# Train on 732390 samples, validate on 81377 samples
# Epoch 1/15
# 732390/732390 [==============================] - 50s 69us/sample - loss: 1669007.9843 - mean_absolute_error: 843.8036 - val_loss: 1164635.7092 - val_mean_absolute_error: 743.0295
# Epoch 2/15
# 732390/732390 [==============================] - 50s 68us/sample - loss: 1171120.6705 - mean_absolute_error: 724.3409 - val_loss: 1111668.1403 - val_mean_absolute_error: 693.7537
# Epoch 3/15
# 732390/732390 [==============================] - 49s 67us/sample - loss: 1106761.9880 - mean_absolute_error: 704.0231 - val_loss: 991575.1513 - val_mean_absolute_error: 672.7311
# Epoch 4/15
# 732390/732390 [==============================] - 49s 67us/sample - loss: 1068079.3162 - mean_absolute_error: 692.4590 - val_loss: 1011870.0158 - val_mean_absolute_error: 688.2426
# Epoch 5/15
# 732390/732390 [==============================] - 55s 75us/sample - loss: 1040208.6472 - mean_absolute_error: 683.7611 - val_loss: 969554.6482 - val_mean_absolute_error: 670.3452
# Epoch 6/15
# 732390/732390 [==============================] - 49s 67us/sample - loss: 1015750.5548 - mean_absolute_error: 675.8318 - val_loss: 988043.4292 - val_mean_absolute_error: 681.6380
# Epoch 7/15
# 732390/732390 [==============================] - 49s 67us/sample - loss: 993298.8248 - mean_absolute_error: 669.3033 - val_loss: 941553.6834 - val_mean_absolute_error: 659.0141
# Epoch 8/15
# 732390/732390 [==============================] - 50s 68us/sample - loss: 972580.2251 - mean_absolute_error: 662.8051 - val_loss: 943582.4515 - val_mean_absolute_error: 656.8453
# Epoch 9/15
# 732390/732390 [==============================] - 49s 67us/sample - loss: 955661.2728 - mean_absolute_error: 657.3719 - val_loss: 912030.6714 - val_mean_absolute_error: 645.1823
# Epoch 10/15
# 732390/732390 [==============================] - 49s 67us/sample - loss: 932155.4979 - mean_absolute_error: 649.9688 - val_loss: 915346.4015 - val_mean_absolute_error: 645.2188
# Epoch 11/15
# 732390/732390 [==============================] - 53s 73us/sample - loss: 914243.2791 - mean_absolute_error: 643.7151 - val_loss: 982371.3974 - val_mean_absolute_error: 660.0645
# Epoch 12/15
# 732390/732390 [==============================] - 63s 86us/sample - loss: 904296.9130 - mean_absolute_error: 639.4683 - val_loss: 870504.9591 - val_mean_absolute_error: 634.3904
# Epoch 13/15
# 732390/732390 [==============================] - 63s 86us/sample - loss: 893026.1422 - mean_absolute_error: 635.2429 - val_loss: 845349.7175 - val_mean_absolute_error: 617.8019
# Epoch 14/15
# 732390/732390 [==============================] - 63s 86us/sample - loss: 877756.7569 - mean_absolute_error: 629.7043 - val_loss: 857279.3622 - val_mean_absolute_error: 636.7107
# Epoch 15/15
# 732390/732390 [==============================] - 63s 86us/sample - loss: 869445.3310 - mean_absolute_error: 626.2299 - val_loss: 830779.2567 - val_mean_absolute_error: 622.5027
# Metric  loss : 823957.52
# Metric  mean_absolute_error : 616.48

# %%
#Plotting the Loss Metric Across Epochs
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Model's Training & Validation loss across epochs")
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
#Testing the Model Manually
#Manually predicting from the model, instead of using model's evaluate function
y_test["Prediction"] = model.predict(x_test)
y_test.columns = ["Actual Sales","Predicted Sales"]
print(y_test.head(10))
#Manually predicting from the model, instead of using model's evaluate function
from sklearn.metrics import mean_squared_error, mean_absolute_error
print("MSE :",mean_squared_error(y_test["Actual Sales"].values,y_test["Predicted Sales"].values))
print("MAE :",mean_absolute_error(y_test["Actual Sales"].values,y_test["Predicted Sales"].values))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [82], in <cell line: 4>()
#       1 #Testing the Model Manually
#       2 #Manually predicting from the model, instead of using model's evaluate function
#       3 y_test["Prediction"] = model.predict(x_test)
# ----> 4 y_test.columns = ["Actual Sales","Predicted Sales"]
#       5 print(y_test.head(10))
#       6 #Manually predicting from the model, instead of using model's evaluate function
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5588, in NDFrame.__setattr__(self, name, value)
#    5586 try:
#    5587     object.__getattribute__(self, name)
# -> 5588     return object.__setattr__(self, name, value)
#    5589 except AttributeError:
#    5590     pass
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:769, in NDFrame._set_axis(self, axis, labels)
#     767 def _set_axis(self, axis: int, labels: Index) -> None:
#     768     labels = ensure_index(labels)
# --> 769     self._mgr.set_axis(axis, labels)
#     770     self._clear_item_cache()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py:214, in BaseBlockManager.set_axis(self, axis, new_labels)
#     212 def set_axis(self, axis: int, new_labels: Index) -> None:
#     213     # Caller is responsible for ensuring we have an Index object.
# --> 214     self._validate_set_axis(axis, new_labels)
#     215     self.axes[axis] = new_labels
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\base.py:69, in DataManager._validate_set_axis(self, axis, new_labels)
#      66     pass
#      68 elif new_len != old_len:
# ---> 69     raise ValueError(
#      70         f"Length mismatch: Expected axis has {old_len} elements, new "
#      71         f"values have {new_len} elements"
#      72     )
#
# ValueError: Length mismatch: Expected axis has 3 elements, new values have 2 elements

# %% [markdown]
# 6.chạy ví dụ chap 4[0.2]

# %%
#Exploring the Data
#Import the necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#Import the 2 datasets provided in the Zip Folder
df = pd.read_csv("act_train.csv")
people = pd.read_csv("people.csv")
#Explore the shape of the datasets
print("Shape of DF:",df.shape)
print("Shape of People DF:",people.shape)

# %%
#Explore the contents of the first dataset
df.head()

# %%
#Calculating the % of Null values in each column for activity data
df.isnull().sum()/df.shape[0]

# %%
#Explore the contents of People dataset
people.head()

# %%
#Calculate the % of null values in for the entire dataset
people.isnull().sum().sum()

# %%
#Create the list of columns to drop from activity data
columns_to_remove = ["char_"+str(x) for x in np.arange(1,10)]
print("Columns to remove:",columns_to_remove)
#Remove the columns from the activity data
df = df[list(set(df.columns) - set(columns_to_remove))]
#Rename the 2 columns to avoid name clashes in merged data
df = df.rename(columns={"date":"activity_date","char_10":"activity_type"})
#Replace nulls in the activity_type column with the mode
df["activity_type"] = df["activity_type"].fillna(df["activity_type"].mode()[0])
#Print the shape of the final activity dataset
print("Shape of DF:",df.shape)

# %%
#Merge the 2 datasets on 'people_id' key
df_new = df.merge(people,on=["people_id"],how="inner")
print("Shape before merging:",df.shape)
print("Shape after merging :",df_new.shape)

# %%
print("Unique values for outcome:",df_new["outcome"].unique())
print("\nPercentage of distribution for outcome-")
print(df_new["outcome"].value_counts()/df_new.shape[0])

# %%
#Data Engineering
#Checking the distinct datatypes in the dataset
print("Distinct DataTypes:",list(df_new.dtypes.unique()))

# %%
#Create a temp dataset with the datatype of columns
temp = pd.DataFrame(df_new.dtypes)
temp.columns = ["DataType"]
#Create a list with names of all Boolean columns
boolean_columns = temp.index[temp["DataType"] == 'bool'].values
print("Boolean columns - \n",boolean_columns)
#Convert all boolean columns to Binary numeric values
for column in boolean_columns:
    df_new[column] = np.where(df_new[column] == True,1,0)
print("\nDistinct DataTypes after processing:",df.dtypes.unique())
# Out:
# Boolean columns -
#  ['char_10' 'char_11' 'char_12' 'char_13' 'char_14' 'char_15' 'char_16'
#  'char_17' 'char_18' 'char_19' 'char_20' 'char_21' 'char_22' 'char_23'
#  'char_24' 'char_25' 'char_26' 'char_27' 'char_28' 'char_29' 'char_30'
#  'char_31' 'char_32' 'char_33' 'char_34' 'char_35' 'char_36' 'char_37']
#
# Distinct DataTypes after processing: [dtype('int64') dtype('O')]

# %%
#Extracting the object columns from the above dataframe
categorical_columns = temp.index[temp["DataType"] == 'O'].values
#Check the number of distinct values in each categorical column
for column in categorical_columns:
    print(column+" column has :",str(len(df_new[column].unique()))+" distinct values")
# Out:
# people_id column has : 151295 distinct values
# activity_type column has : 6515 distinct values
# activity_date column has : 411 distinct values
# activity_category column has : 7 distinct values
# activity_id column has : 2197291 distinct values
# char_1 column has : 2 distinct values
# group_1 column has : 29899 distinct values
# char_2 column has : 3 distinct values
# date column has : 1196 distinct values
# char_3 column has : 43 distinct values
# char_4 column has : 25 distinct values
# char_5 column has : 9 distinct values
# char_6 column has : 7 distinct values
# char_7 column has : 25 distinct values
# char_8 column has : 8 distinct values
# char_9 column has : 9 distinct values

# %%
#Create date related features for 'date' in customer data
df_new["date"] = pd.to_datetime(df_new["date"])
df_new["Year"] = df_new["date"].dt.year
df_new["Month"] = df_new["date"].dt.month
df_new["Quarter"] = df_new["date"].dt.quarter
df_new["Week"] = df_new["date"].dt.week
df_new["WeekDay"] = df_new["date"].dt.weekday
df_new["Day"] = df_new["date"].dt.day
#Create date related features for 'date' in activity data
df_new["activity_date"] = pd.to_datetime(df_new["activity_date"])
df_new["Activity_Year"] = df_new["activity_date"].dt.year
df_new["Activity_Month"] = df_new["activity_date"].dt.month
df_new["Activity_Quarter"] = df_new["activity_date"].dt.quarter
df_new["Activity_Week"] = df_new["activity_date"].dt.week
df_new["Activity_WeekDay"] = df_new["activity_date"].dt.weekday
df_new["Activity_Day"] = df_new["activity_date"].dt.day
#Delete the original date columns
del(df_new["date"])
del(df_new["activity_date"])
print("Shape of data after create Date Features:",df_new.shape)
# Out:
# C:\Users\Dell Precision 7510\AppData\Local\Temp\ipykernel_12872\1004644207.py:6: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df_new["Week"] = df_new["date"].dt.week
# C:\Users\Dell Precision 7510\AppData\Local\Temp\ipykernel_12872\1004644207.py:14: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df_new["Activity_Week"] = df_new["activity_date"].dt.week
# Shape of data after create Date Features: (2197291, 56)

# %%
print(df_new[["people_id","activity_type","activity_id","group_1"]].head())
# Out:
#   people_id activity_type   activity_id      group_1
# 0   ppl_100       type 76  act2_1734928  group 17304
# 1   ppl_100        type 1  act2_2434093  group 17304
# 2   ppl_100        type 1  act2_3404049  group 17304
# 3   ppl_100        type 1  act2_3651215  group 17304
# 4   ppl_100        type 1  act2_4109017  group 17304

# %%
#For people ID, we would need to extract values after '_'
df_new['people_id'] = df_new.people_id.apply(lambda x:x.split("_")[1])
df_new['people_id'] = pd.to_numeric(df_new.people_id)
#For activity ID also, we would need to extract values after '_'
df_new['activity_id'] = df_new.activity_id.apply(lambda x:x.split("_")[1])
df_new['activity_id'] = pd.to_numeric(df_new.activity_id)
#Double check the new values in the dataframe
print(df_new[["people_id","activity_type","activity_id","group_1"]].head())
# Out:
#    people_id activity_type  activity_id      group_1
# 0      100.0       type 76    1734928.0  group 17304
# 1      100.0        type 1    2434093.0  group 17304
# 2      100.0        type 1    3404049.0  group 17304
# 3      100.0        type 1    3651215.0  group 17304
# 4      100.0        type 1    4109017.0  group 17304

# %%
#For group_1 , we would need to extract values after "
df_new.group_1 = df_new.group_1.apply(lambda x:x.split()[1])
df_new.group_1 = pd.to_numeric(df_new.group_1)
#For activity_type , we would need to extract values after "
df_new.activity_type = df_new.activity_type.apply(lambda x:x.split()[1])
df_new.activity_type = pd.to_numeric(df_new.activity_type)

# %%
print(df_new[["people_id","activity_type","activity_id","group_1"]].head())
# Out:
#    people_id  activity_type  activity_id  group_1
# 0      100.0             76    1734928.0    17304
# 1      100.0              1    2434093.0    17304
# 2      100.0              1    3404049.0    17304
# 3      100.0              1    3651215.0    17304
# 4      100.0              1    4109017.0    17304

# %%
df_new
# Out:
#          outcome  people_id  activity_type activity_category  activity_id  \
# 0              0      100.0             76            type 4    1734928.0
# 1              0      100.0              1            type 2    2434093.0
# 2              0      100.0              1            type 2    3404049.0
# 3              0      100.0              1            type 2    3651215.0
# 4              0      100.0              1            type 2    4109017.0
# ...          ...        ...            ...               ...          ...
# 2197286        1    99994.0            418            type 4    4668076.0
# 2197287        1    99994.0           1832            type 4    4743548.0
# 2197288        1    99994.0              1            type 2     536973.0
# 2197289        1    99994.0            199            type 4     688656.0
# 2197290        1    99994.0              1            type 2     715089.0
#
#          char_1  group_1  char_2  char_3  char_4  ... Quarter Week WeekDay  \
# 0        type 2    17304  type 2  type 5  type 5  ...       2   26       1
# 1        type 2    17304  type 2  type 5  type 5  ...       2   26       1
# 2        type 2    17304  type 2  type 5  type 5  ...       2   26       1
# 3        type 2    17304  type 2  type 5  type 5  ...       2   26       1
# 4        type 2    17304  type 2  type 5  type 5  ...       2   26       1
# ...         ...      ...     ...     ...     ...  ...     ...  ...     ...
# 2197286  type 2    17764  type 3  type 2  type 7  ...       1    1       4
# 2197287  type 2    17764  type 3  type 2  type 7  ...       1    1       4
# 2197288  type 2    17764  type 3  type 2  type 7  ...       1    1       4
# 2197289  type 2    17764  type 3  type 2  type 7  ...       1    1       4
# 2197290  type 2    17764  type 3  type 2  type 7  ...       1    1       4
#
#         Day Activity_Year  Activity_Month  Activity_Quarter  Activity_Week  \
# 0        29          2023               8                 3             34
# 1        29          2022               9                 3             39
# 2        29          2022               9                 3             39
# 3        29          2023               8                 3             31
# 4        29          2023               8                 3             34
# ...      ..           ...             ...               ...            ...
# 2197286   6          2023               6                 2             24
# 2197287   6          2023               3                 1             13
# 2197288   6          2023               1                 1              3
# 2197289   6          2023               5                 2             18
# 2197290   6          2023               6                 2             24
#
#          Activity_WeekDay  Activity_Day
# 0                       5            26
# 1                       1            27
# 2                       1            27
# 3                       4             4
# 4                       5            26
# ...                   ...           ...
# 2197286                 4            16
# 2197287                 3            30
# 2197288                 3            19
# 2197289                 1             2
# 2197290                 3            15
#
# [2197291 rows x 56 columns]

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
#Define a function that will intake the raw dataframe and the column name and return a one hot encoded DF
def create_ohe(df, col):
    le = LabelEncoder()
    a=le.fit_transform(df_new[col]).reshape(-1,1)
    ohe = OneHotEncoder(sparse=False)
    column_names = [col+ "_"+ str(i) for i in le.classes_]
    return(pd.DataFrame(ohe.fit_transform(a),columns =column_names))
#Since the above function converts the column, one at a time
#We create a loop to create the final dataset with all features
target = ["outcome"]
numeric_columns = list(set(temp.index[(df_new.dtypes =="float64") | (df_new.dtypes =="int64")].values) - set(target))
temp = df_new[numeric_columns]
for column in categorical_columns:
    temp_df = create_ohe(df_new,column)
    temp = pd.concat([temp,temp_df],axis=1)
print("\nShape of final df after onehot encoding:",temp.shape)

# %%
from sklearn.model_selection import train_test_split
#split the final dataset into train and test with 80:20
x_train, x_test, y_train, y_test = train_test_split(temp,df_new[target], test_size=0.2,random_state=2018)
#split the train dataset further into train and validation with 90:10
x_train, x_val, y_train, y_val = train_test_split(x_train,y_train, test_size=0.1, random_state=2018)
#Check the shape of each new dataset created
print("Shape of x_train:",x_train.shape)
print("Shape of x_test:",x_test.shape)
print("Shape of x_val:",x_val.shape)
print("Shape of y_train:",y_train.shape)
print("Shape of y_test:",y_test.shape)
print("Shape of y_val:",y_val.shape)

# %%
#Defining Model Baseline Accuracy
#Checking the distribution of values in the target
df_new["outcome"].value_counts()/df_new.shape[0]

# %%
#Designing the DNN for Classification
from keras.models import Sequential
from keras.layers import Dense
#Design the deep neural network [Small + 1 layer]
model = Sequential()
model.add(Dense(256,input_dim = x_train.shape[1],activation="relu"))
model.add(Dense(256,activation="relu"))
model.add(Dense(1,activation = "sigmoid")) #activation =sigmoid for binary classification
model.compile(optimizer = "Adam",loss="binary_crossentropy",metrics=["accuracy"])
model.fit(x_train,y_train, validation_data = (x_val,y_val),epochs=3, batch_size=64)

# %%
#Design the deep neural network [Small + 2 layers]
model = Sequential()
model.add(Dense(256,input_dim = x_train.shape[1],activation="relu"))
model.add(Dense(256,activation="relu"))
model.add(Dense(1,activation = "sigmoid"))
model.compile(optimizer = "Adam",loss="binary_crossentropy",metrics=["accuracy"])
model.fit(x_train,y_train, validation_data = (x_val,y_val),epochs=3, batch_size=64)

# %%
#Design the deep neural network [Medium + 1 layers]
model = Sequential()
model.add(Dense(512,input_dim = x_train.shape[1],activation="relu"))
model.add(Dense(1,activation = "sigmoid"))
model.compile(optimizer = "Adam",loss="binary_crossentropy",metrics=["accuracy"])
model.fit(x_train,y_train, validation_data = (x_val,y_val),epochs=3, batch_size=64)

# %%
#Design the deep neural network [Medium + 2 layers]
model = Sequential()
model.add(Dense(512,input_dim = x_train.shape[1],activation="relu"))
model.add(Dense(512,activation="relu"))
model.add(Dense(1,activation = "sigmoid"))
model.compile(optimizer = "Adam",loss="binary_crossentropy",metrics=["accuracy"])
model.fit(x_train,y_train, validation_data = (x_val,y_val),epochs=3, batch_size=64)

# %%
#Revisiting the Data
#Standardize, Normalize, or Scale the Data
#Create a dummy input
dummy_input = np.arange(1,10)
print("Dummy Input = ",dummy_input)
from sklearn.preprocessing import StandardScaler
#Create a standardscaler instance and fit the data
scaler = StandardScaler()
output = scaler.fit_transform(dummy_input.reshape(-1,1))
print("Output =\n ",list(output))
print("Output's Mean = ",output.mean())
print("Output's Std Dev = ",output.std())
print("\nAfter Inverse Transforming = \n",list(scaler.inverse_transform(output)))

# %%
#Transforming the Input Data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x_train)
x_train_scaled = scaler.transform(x_train)
x_val_scaled = scaler.transform(x_val)
x_test_scaled = scaler.transform(x_test)

# %%
#DNNs for Classification with Improved Data
from keras import Sequential
from keras.layers import Dense
model = Sequential()
model.add(Dense(512,input_dim = x_train_scaled.shape[1],activation="relu"))
model.add(Dense(1,activation = "sigmoid"))
model.compile(optimizer = "Adam",loss="binary_crossentropy",metrics=["accuracy"])
model.fit(x_train_scaled,y_train, validation_data =(x_val_scaled,y_val), epochs=3, batch_size=64)

# %%
result = model.evaluate(x_test_scaled,y_test)
for i in range(len(model.metrics_names)):
    print("Metric ",model.metrics_names[i],":",str(round(result[i],2)))

# %%
#Designing the Deep Neural Network [Medium – 2 Layers]
model = Sequential()
model.add(Dense(512,input_dim = x_train_scaled.shape[1],activation="relu"))
model.add(Dense(512,activation="relu"))
model.add(Dense(1,activation = "sigmoid"))
model.compile(optimizer = "Adam",loss="binary_crossentropy",metrics=["accuracy"])
model.fit(x_train_scaled,y_train, validation_data = (x_val_scaled,y_val),epochs=3, batch_size=64)

# %%
#Designing the network Deep Neural Network – [Large + 2 Layers]
model = Sequential()
model.add(Dense(1024,input_dim = x_train_scaled.shape[1],activation="relu"))
model.add(Dense(1024,activation = "relu"))
model.add(Dense(1,activation = "sigmoid"))
model.compile(optimizer = "Adam",loss="binary_crossentropy",metrics=["accuracy"])
model.fit(x_train_scaled,y_train, validation_data =(x_val_scaled,y_val),epochs=3, batch_size=64)

# %%
#Designing the network Deep Neural Network – [Medium + 2 Layers]
model = Sequential()
model.add(Dense(512,input_dim = x_train_scaled.shape[1],activation="relu"))
model.add(Dense(512,activation = "relu"))
model.add(Dense(1,activation = "sigmoid"))
model.compile(optimizer = "Adam",loss="binary_crossentropy",metrics=["accuracy"])
model.fit(x_train_scaled,y_train, validation_data = (x_val_scaled,y_val),epochs=15, batch_size=64)

# %%
result = model.evaluate(x_test_scaled,y_test)
for i in range(len(model.metrics_names)):
    print("Metric ",model.metrics_names[i],":",str(round(result[i],2)))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title("Model's Training & Validation loss across epochs")
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title("Model's Training & Validation Accuracy across epochs")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
